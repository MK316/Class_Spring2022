# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Class_Spring2022/blob/main/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📖 Week11 (6/21, Tuesday)
#
# ## #️⃣ Todo list:
#
# 1. **Phonics - part 2**
# 2. Learning goals:
# * **Vocabulary review** learning with sounds (N, V, Adj, Adv)
# * **Grammar review:** verb tense review practice
# * Class activities with **English expressions**
#
# 3. **Final exam preview**

# %% [markdown]
# # **Part 1: Phonics part 2**
#
# * Keywords: English 15 vowels
# * Texts from RE:
# [Ch01](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/Ch01.Visual.Village.txt), [Ch02](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/Ch02_Living%20light.txt), [Ch03](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/Ch03B.txt), [Ch05](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/RE.ch05.txt) & [Ch06](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/Ch06.txt); [total](https://raw.githubusercontent.com/MK316/Class_Spring2022/main/ER_0102030506.txt)

# %%
#@markdown 🌱 How many texts to paste?
num_of_texts = "1"  #@param ["1","2","3","4","5"]
#@markdown (Note: An empty box will pop-up to take your text one at a time.)
numtexts = int(num_of_texts)
text = str()

for i in range(1, numtexts+1):
  print('Paste your text; ')
  t1 = input()
  text = text + " " + str(t1)
  total = text
  if i < (numtexts+1):
    i = i+1
  else:
    text = total
print("Total length: %d"%len(total))

#@markdown 🌱 Number of words in the combined text:
split_text = text.split(" ")
print("The total number of words: %d"%len(split_text))
# Out:
# Paste your text;
# ...

# %% [markdown]
# ## 📕 **[3] Words in context**

# %%
#@markdown 🔰 Import packages {nltk.sent_tokenize}
# %%capture
import nltk
from nltk import sent_tokenize
nltk.download("punkt")
sents = nltk.sent_tokenize(text)

# %%
#@markdown 🔰 Find sentences with specific word: pop-up window
import re

word_to_search = input()
w = str(word_to_search)

results = [s for s in sents if bool(re.findall(w,s)) == 1 ]
results

# %% [markdown]
# ##**High frequency words**

# %%
#@markdown 📕 Import packages {nltk}
# %%capture
import nltk
from nltk import word_tokenize, sent_tokenize
nltk.download("punkt")
from nltk.tokenize import RegexpTokenizer

# import stopwords from nltk.corpus

from nltk.corpus import stopwords
nltk.download("stopwords")

# %%
#@markdown 📕 Add new words to the stopword list, if you want:
stop_words = set(stopwords.words("english"))

#add words that aren't in the NLTK stopwords list
new_stopwords = ['us']
new_stopwords_list = stop_words.union(new_stopwords)

print(new_stopwords_list)
# Out:
# {'herself', 'of', 'other', 'can', 'while', 'under', 'your', 'any', 'been', 'isn', 'each', 'nor', 'by', 'weren', 'she', 'further', 'aren', 'the', 'with', 'above', 'what', 'wouldn', 've', 'once', 'haven', 'up', "you're", 'through', 'my', 'having', "don't", 'at', 'does', 'just', 'on', 'about', 'over', 'between', 'd', 'did', "won't", 'are', 'itself', "weren't", 'mustn', 'shan', 'their', 'yourself', 'again', 're', 'don', 'didn', 'from', 'because', 'me', 'than', 'ma', "wasn't", 'all', 'during', 'where', "that'll", 'after', 'how', 'yourselves', 'is', 'more', 'no', 'its', 'has', 'y', "didn't", 'am', 'those', 'both', 'were', 'own', 'couldn', "you'd", 'when', 'such', 'them', 'wasn', 'a', 'most', 'against', 'hadn', 'that', 'do', 'shouldn', 's', 'not', 'theirs', 'some', 'off', 'for', 'there', 'him', 'ain', 'why', 'now', "doesn't", 'ours', 'our', 'before', 'very', 'until', "it's", "hadn't", 'or', "isn't", 'if', "hasn't", 'and', 'but', 'into', "you've", 'in', 'm', 'so', 'was', 'here', 'should', "s
# ...

# %%
#@markdown 📕 Preprocessing Remove stopwords, numbers, 2 character words
import re
text = text.lower()
retokenize =RegexpTokenizer("[\w]+")
words = retokenize.tokenize(text)

numbers = re.findall('[0-9]+[0-9]+',text)
words = [w for w in words if not w in numbers]
words = [w for w in words if len(w) > 2]

#@markdown Tokenized words after filtering new stop words:
print('Number of words before stopwords: %d'%len(words))
words = [w for w in words if not w in new_stopwords_list]
print('Number of words after stopwords: %d'%len(words))
# Out:
# Number of words before stopwords: 3444
# Number of words after stopwords: 2362

# %%
#@markdown 📕 Frequency distribution
number_of_words = "100" #@param ["10","20","30","50","100"]
n = int(number_of_words)

fd = nltk.FreqDist(words).most_common(n)
print(fd[:10])

import pandas as pd

df = pd.DataFrame()
wlist = []
freq = []

for i in range(0,n):
  wlist.append(fd[i][0])
  freq.append(fd[i][1])

df['ID'] = range(1,n+1)
df['Words'] = wlist
df['Freq'] = freq

print(df[:n])

df.to_csv(r'/content/freqlist_%d.csv'%n,index=False)
# Out:
# [('light', 22), ('people', 20), ('money', 19), ('dna', 15), ('ancient', 14), ('new', 13), ('one', 13), ('genetic', 13), ('today', 12), ('make', 12)]
#      ID     Words  Freq
# 0     1     light    22
# 1     2    people    20
# 2     3     money    19
# 3     4       dna    15
# 4     5   ancient    14
# ..  ...       ...   ...
# 95   96    number     4
# 96   97      show     4
# 97   98   perhaps     4
# 98   99  language     4
# 99  100     known     4
#
# [100 rows x 3 columns]

# %% [markdown]
# # **Part 2: Learn high frequency words with sounds: gTTS**

# %%
#@markdown 🚩 {gTTS} package installation and import
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
#@markdown Preparing Wordlist: High frequency words 100 (saved as wtext)
wlist = df['Words']
wid = df['ID']
flist = []
for n in range(0, len(wlist)):
  word_with_num = str(wid[n]) + ", " + str(wlist[n])
  flist.append(word_with_num)

wtext = '! '.join(flist)
wtext = "Let me say 100 frequently used words. " + wtext
wtext

# %%
#@markdown 🚩 Getting ready to use { tts ( _text_to_say_) }:
def tts(mytext):

#Install gTTS
# !pip install gTTS
# from gtts import gTTS
# from IPython.display import Audio

  text_to_say = mytext

# Step ⓵ Language to choose:
  language_to_choose = "en" #@param ["en", "fr","ko",'es']
  Slow_speed = "True" #@param ["True","False"]
  # lang = language_to_choose
#@markdown 🌝 Dialect to choose: "com (default)" for General American English, "co.uk" for British, "com.au" for Australian, "co.in" for Indian, "ie" for Ireland accent.  
  dialect = "com" #@param ["com","co.uk","com.au","ca","co.in","ie"]
  print("Play language accent: %s"%language_to_choose)
  print("Play local accent: %s"%dialect)
  language = language_to_choose

# gTTS
  gtts_object = gTTS(text = text_to_say,
                     lang = language, tld = dialect,
                    slow = Slow_speed)
  
# #@markdown Step ③: Create the audio file (.wav) to play:
  gtts_object.save("mytext.wav")

# # Output
  return Audio("mytext.wav")

# %%
# tts(wtext)
# Out:
# Play language accent: en
# Play local accent: com
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Words in context**

# %% [markdown]
# 1. At first, red light is absorbed.
# 2. It begins in Africa with a group of people.
# 3. In 2009, yet another high-tech successor to money emerged: Bitcoin.
# 4. The bulk of our DNA is the same.
# 5. Since ancient times, humans have used items to represent value.
# 6. But eventually there arose a new, universal currency: gold.
# 7. No one image gets to be special for long.
# 8. However, genetic traces of the group that made the trip do exist.
# 9. Lydian coins didn't look much like today's coinage.
# 10. However, genetic traces of the group that made the trip do exist.
# 11.Can biotech foods help feed the world?
# 12. Most scientists agree that the main safety issues of GE crops involve not people but the environment.
# 13. No one image gets to be special for long.
# 14. Some GE foods might even be safer than non-GE foods.
# 15. Perhaps about 40,000 years ago, modern humans first advanced into Europe.
# 16. Perhaps about 40,000 years ago, modern humans first advanced into Europe.
# 17. It’s not because there are fewer good images: It’s because there are so many.
# 18. Our obsession with documentation could lead to a radical change in our way of being.
# 19. Perhaps about 40,000 years ago, modern humans first advanced into Europe.
# 20. It begins in Africa with a group of people.
# 21. At first, red light is absorbed.
# 22. Their value was fixed by the metal in them.
# 23. Can biotech foods help feed the world?
# 24. However, biotech foods have had problems in the past.
# 25. Rat genes have been inserted into lettuce plants to make a plant that produces vitamin C.
# 26. Some are like ocean fireflies.
# 27. A study compared mtDNA from people around the world.
# 28. Digital images can be altered in ways (the naked eye might never notice.)
# 29. In fact, most of the ocean is as black as the night sky.
# 30. Lydian coins didn't look much like today's coinage.
# 31. The human genetic code, or genome, is 99.9 percent identical throughout the world.
# 32. Moving genes across dramatically different species also makes critics nervous.
# 33. "A coastal route would have been the easiest way in," says Wells.’
# 34. Lydian coins didn't look much like today's coinage.
# 35. It’s not because there are fewer good images: It’s because there are so many.
# 36. No one image gets to be special for long.
# 37. Today, however, digital images can be altered in ways the naked eye might never notice.
# 38. One piece might signify a measure of grain
# 39. They began using small pieces of baked clay.
# 40. There are also glowing bacteria.
# 41. Can biotech foods help feed the world?
# 42. But the real biological light show takes place in the sea.
# 43. Genetic engineering (GE) of crops and animals through the manipulation of DNA is producing a revolution in food production.
# 44. Since ancient times, humans have used items to represent value.
# 45. Scientists can trace their ancestral connections.
# 46. It begins in Africa with a group of people.
# 47. Once in Asia, genetic evidence suggests, the population split.
# 48. Besides exchanging money and goods, traders also spread religious beliefs, knowledge, and new inventions.
# 49. Other sea species use light to survive in the upper layers.
# 50. If everyone has a camera, Big Brother isn’t the only one watching.

# %%
# Paste texts from the above:

# elist = input()
# tts(elist)

# %% [markdown]
# ## **Papago translations:**

# %% [markdown]
# "1. 처음에는 붉은 빛이 흡수된다."
# "2. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다."
# "3. 2009년, 화폐의 또 다른 첨단 기술 후계자가 등장했다. 비트코인."
# "4. 우리 DNA의 대부분은 동일하다."
# "5. 고대부터 인간은 가치를 나타내기 위해 물건을 사용해 왔다."
# "6. 그러나 마침내 새로운 보편적인 화폐인 금이 생겨났다."
# "7. 오랫동안 특별한 이미지는 없습니다."
# "8. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다."
# "9. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다."
# "10. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다."
# "11. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
# "12. 대부분의 과학자들은 GE 작물의 주요 안전 문제가 사람이 아닌 환경을 포함한다는 것에 동의한다."
# "13. 어떤 이미지도 오랫동안 특별해지지 않습니다."
# "14. 어떤 GE 식품들은 심지어 비 GE 식품들보다 더 안전할지도 모른다."
# "15. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다."
# "16. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다."
# "17. 좋은 이미지가 적어서가 아니다. 너무 많아서 그래요."
# "18. 문서에 대한 집착은 우리의 삶의 방식에 급격한 변화를 가져올 수 있다."
# "19. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다."
# "20. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다."
# "21. 처음에는 붉은 빛이 흡수된다."
# "22. 그것들의 가치는 그 안에 있는 금속에 의해 고정되었다."
# "23. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
# "24. 그러나 생명공학 식품은 과거에 문제가 있었다."
# "25. 쥐 유전자는 비타민 C를 생산하는 식물을 만들기 위해 상추식물에 삽입되었다."
# "26. 어떤 것들은 바다 반딧불 같다."
# "27. 한 연구는 전 세계 사람들의 mtDNA를 비교했다."
# "28. 디지털 이미지는 (육안으로는 전혀 눈치채지 못할 수도 있는) 방식으로 바뀔 수 있다."
# "29. 사실, 대부분의 바다는 밤하늘만큼 검다."
# "30. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다."
# "31. 인간의 유전자 코드, 즉 게놈은 전 세계적으로 99.9퍼센트 동일하다."
# "32. 극적으로 다른 종에 걸쳐 유전자를 옮기는 것 또한 비평가들을 불안하게 만든다."
# "33. 웰즈는 "해안 항로가 가장 쉬운 길이었을 것"이라고 말했다."
# "34. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다."
# "35. 좋은 이미지가 적어서가 아니다. 너무 많아서 그래요."
# "36. 오랫동안 특별한 이미지는 없습니다."
# "37. 그러나 오늘날, 디지털 이미지는 육안으로는 결코 눈치채지 못할 방법으로 바뀔 수 있다."
# "38. 한 조각은 곡물의 양을 의미할 수 있다."
# "39. 그들은 구운 점토 조각들을 사용하기 시작했다."
# "40. 빛나는 박테리아도 있습니다."
# "41. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
# "42. 하지만 진짜 생물학적 빛의 쇼는 바다에서 열립니다."
# "43. DNA 조작을 통한 농작물과 동물의 유전자 공학이 식량 생산에 혁명을 일으키고 있다."
# "44. 고대부터 인간은 가치를 나타내기 위해 물건을 사용해 왔다."
# "45. 과학자들은 그들의 조상들의 연관성을 추적할 수 있다."
# "46. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다."
# "47. 일단 아시아에 들어오면, 유전적 증거에 따르면 개체수가 쪼개졌다."
# "48. 돈과 상품을 교환하는 것 외에도, 무역업자들은 또한 종교적인 믿음, 지식, 그리고 새로운 발명품들을 퍼뜨린다."
# "49. 다른 바다 종들은 윗층에서 살아남기 위해 빛을 사용합니다."
# "50. 모두가 카메라를 가지고 있다면, 빅 브라더만 보고 있는 것은 아니다."

# %%
klist = input()
# Out:
# "1. 처음에는 붉은 빛이 흡수된다." "2. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다." "3. 2009년, 화폐의 또 다른 첨단 기술 후계자가 등장했다. 비트코인." "4. 우리 DNA의 대부분은 동일하다." "5. 고대부터 인간은 가치를 나타내기 위해 물건을 사용해 왔다." "6. 그러나 마침내 새로운 보편적인 화폐인 금이 생겨났다." "7. 오랫동안 특별한 이미지는 없습니다." "8. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다." "9. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다." "10. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다." "11. 생명공학 식품이 세계를 먹여 살릴 수 있을까?" "12. 대부분의 과학자들은 GE 작물의 주요 안전 문제가 사람이 아닌 환경을 포함한다는 것에 동의한다." "13. 어떤 이미지도 오랫동안 특별해지지 않습니다." "14. 어떤 GE 식품들은 심지어 비 GE 식품들보다 더 안전할지도 모른다." "15. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다." "16. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다." "17. 좋은 이미지가 적어서가 아니다. 너무 많아서 그래요." "18. 문서에 대한 집착은 우리의 삶의 방식에 급격한 변화를 가져올 수 있다." "19. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다." "20. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다." "21. 처음에는 붉은 빛이 흡수된다." "22. 그것들의 가치는 그 안에 있는 금속에 의해 고정되었다." "23. 생명공학 식품이 세계를 먹여 살릴 수 있을까?" "24. 그러나 생명공학 식품은 과거에 문제가 있었다." "25. 쥐 유전자는 비타민 C를 생산하는 식물을 만들기 위해 상추식물에 삽입되었다." "26. 어떤 것들은 바다 반딧불 같다." "27. 한 연구는 전 세계 사람들의 mtDNA를 비교했다." "28. 디지털 이미지는 
# ...

# %% [markdown]
# # Run from here

# %%
#@markdown 🚩 Getting ready to use { ktts ( _text_to_say_) }:
def ktts(mytext):

#Install gTTS
# !pip install gTTS
# from gtts import gTTS
# from IPython.display import Audio

  text_to_say = mytext

# Step ⓵ Language to choose:
  language_to_choose = "ko" #@param ["en", "fr","ko",'es']
  Slow_speed = "False" #@param ["True","False"]
  # lang = language_to_choose
#@markdown 🌝 Dialect to choose: "com (default)" for General American English, "co.uk" for British, "com.au" for Australian, "co.in" for Indian, "ie" for Ireland accent.  
  dialect = "com" #@param ["com","co.uk","com.au","ca","co.in","ie"]
  print("Play language accent: %s"%language_to_choose)
  print("Play local accent: %s"%dialect)
  language = language_to_choose

# gTTS
  gtts_object = gTTS(text = text_to_say,
                     lang = language, tld = dialect,
                    slow = Slow_speed)
  
# #@markdown Step ③: Create the audio file (.wav) to play:
  gtts_object.save("mytext.wav")

# # Output
  return Audio("mytext.wav")

# %%
# ktts(klist)

# %% [markdown]
# # Sentence by sentence

# %%
import re

# %%
# ko_list = input()
# ko_list = list(ko_list)
# Out:
# d

# %%
ko_list = ["1. 처음에는 붉은 빛이 흡수된다.", 
"2. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다.", 
"3. 2009년, 화폐의 또 다른 첨단 기술 후계자가 등장했다. 비트코인.", 
"4. 우리 DNA의 대부분은 동일하다.", 
"5. 고대부터 인간은 가치를 나타내기 위해 물건을 사용해 왔다.", 
"6. 그러나 마침내 새로운 보편적인 화폐인 금이 생겨났다.", 
"7. 오랫동안 특별한 이미지는 없습니다.", 
"8. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다.", 
"9. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다.", 
"10. 그러나 여행을 한 그룹의 유전적 흔적은 존재한다.", 
"11. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
"12. 대부분의 과학자들은 GE 작물의 주요 안전 문제가 사람이 아닌 환경을 포함한다는 것에 동의한다.", 
"13. 어떤 이미지도 오랫동안 특별해지지 않습니다.", 
"14. 어떤 GE 식품들은 심지어 비 GE 식품들보다 더 안전할지도 모른다.", 
"15. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다.", 
"16. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다.", 
"17. 좋은 이미지가 적어서가 아니다. 너무 많아서 그래요.", 
"18. 문서에 대한 집착은 우리의 삶의 방식에 급격한 변화를 가져올 수 있다.", 
"19. 아마도 약 40,000년 전에, 현대 인류는 처음으로 유럽으로 진출했다.", 
"20. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다.", 
"21. 처음에는 붉은 빛이 흡수된다.", 
"22. 그것들의 가치는 그 안에 있는 금속에 의해 고정되었다.", 
"23. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
"24. 그러나 생명공학 식품은 과거에 문제가 있었다.", 
"25. 쥐 유전자는 비타민 C를 생산하는 식물을 만들기 위해 상추식물에 삽입되었다.", 
"26. 어떤 것들은 바다 반딧불 같다.", 
"27. 한 연구는 전 세계 사람들의 mtDNA를 비교했다.", 
"28. 디지털 이미지는 (육안으로는 전혀 눈치채지 못할 수도 있는) 방식으로 바뀔 수 있다.", 
"29. 사실, 대부분의 바다는 밤하늘만큼 검다.", 
"30. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다.", 
"31. 인간의 유전자 코드, 즉 게놈은 전 세계적으로 99.9퍼센트 동일하다.", 
"32. 극적으로 다른 종에 걸쳐 유전자를 옮기는 것 또한 비평가들을 불안하게 만든다.", 
"33. 웰즈는 '해안 항로가 가장 쉬운 길이었을 것'이라고 말했다.", 
"34. 리디아 동전은 오늘날의 동전과 많이 닮지 않았다.", 
"35. 좋은 이미지가 적어서가 아니다. 너무 많아서 그래요.", 
"36. 오랫동안 특별한 이미지는 없습니다.", 
"37. 그러나 오늘날, 디지털 이미지는 육안으로는 결코 눈치채지 못할 방법으로 바뀔 수 있다.", 
"38. 한 조각은 곡물의 양을 의미할 수 있다.", 
"39. 그들은 구운 점토 조각들을 사용하기 시작했다.", 
"40. 빛나는 박테리아도 있습니다.", 
"41. 생명공학 식품이 세계를 먹여 살릴 수 있을까?"
"42. 하지만 진짜 생물학적 빛의 쇼는 바다에서 열립니다.", 
"43. DNA 조작을 통한 농작물과 동물의 유전자 공학이 식량 생산에 혁명을 일으키고 있다.", 
"44. 고대부터 인간은 가치를 나타내기 위해 물건을 사용해 왔다.", 
"45. 과학자들은 그들의 조상들의 연관성을 추적할 수 있다.", 
"46. 그것은 한 무리의 사람들과 함께 아프리카에서 시작한다.", 
"47. 일단 아시아에 들어오면, 유전적 증거에 따르면 개체수가 쪼개졌다.", 
"48. 돈과 상품을 교환하는 것 외에도, 무역업자들은 또한 종교적인 믿음, 지식, 그리고 새로운 발명품들을 퍼뜨린다.", 
"49. 다른 바다 종들은 윗층에서 살아남기 위해 빛을 사용합니다.", 
"50. 모두가 카메라를 가지고 있다면, 빅 브라더만 보고 있는 것은 아니다." 
]

# %%
elist = ["1. At first, red light is absorbed.",
"2. It begins in Africa with a group of people.",
"3. In 2009, yet another high-tech successor to money emerged: Bitcoin.",
"4. The bulk of our DNA is the same.",
"5. Since ancient times, humans have used items to represent value.",
"6. But eventually there arose a new, universal currency: gold.",
"7. No one image gets to be special for long.",
"8. However, genetic traces of the group that made the trip do exist.",
"9. Lydian coins didn't look much like today's coinage.",
"10. However, genetic traces of the group that made the trip do exist.",
"11. Can biotech foods help feed the world?",
"12. Most scientists agree that the main safety issues of GE crops involve not people but the environment.",
"13. No one image gets to be special for long.",
"14. Some GE foods might even be safer than non-GE foods.",
"15. Perhaps about 40,000 years ago, modern humans first advanced into Europe.",
"16. Perhaps about 40,000 years ago, modern humans first advanced into Europe.",
"17. It’s not because there are fewer good images: It’s because there are so many.", 
"18. Our obsession with documentation could lead to a radical change in our way of being.",
"19. Perhaps about 40,000 years ago, modern humans first advanced into Europe.",
"20. It begins in Africa with a group of people.",
"21. At first, red light is absorbed.",
"22. Their value was fixed by the metal in them.",
"23. Can biotech foods help feed the world?",
"24. However, biotech foods have had problems in the past.",
"25. Rat genes have been inserted into lettuce plants to make a plant that produces vitamin C.",
"26. Some are like ocean fireflies.",
"27. A study compared mtDNA from people around the world.",
"28. Digital images can be altered in ways the naked eye might never notice..",
"29. In fact, most of the ocean is as black as the night sky.",
"30. Lydian coins didn't look much like today's coinage.",
"31. The human genetic code, or genome, is 99.9 percent identical throughout the world.",
"32. Moving genes across dramatically different species also makes critics nervous.",
"33. 'A coastal route would have been the easiest way in,' says Wells.",
"34. Lydian coins didn't look much like today's coinage.",
"35. It’s not because there are fewer good images: It’s because there are so many.",
"36. No one image gets to be special for long.",
"37. Today, however, digital images can be altered in ways the naked eye might never notice.",
"38. One piece might signify a measure of grain.",
"39. They began using small pieces of baked clay.",
"40. There are also glowing bacteria.",
"41. Can biotech foods help feed the world?",
"42. But the real biological light show takes place in the sea.", 
"43. Genetic engineering (GE) of crops and animals through the manipulation of DNA is producing a revolution in food production.",
"44. Since ancient times, humans have used items to represent value.",
"45. Scientists can trace their ancestral connections.",
"46. It begins in Africa with a group of people.",
"47. Once in Asia, genetic evidence suggests, the population split.",
"48. Besides exchanging money and goods, traders also spread religious beliefs, knowledge, and new inventions.",
"49. Other sea species use light to survive in the upper layers.",
"50. If everyone has a camera, Big Brother isn’t the only one watching.",]

# %%
num = input()
num = int(num)

ktts(ko_list[num-1])
# Out:
# 4
# Play language accent: ko
# Play local accent: com
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts(elist[num-1])
# Out:
# Play language accent: en
# Play local accent: com
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
