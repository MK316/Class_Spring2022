# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Class_Spring2022/blob/main/Wordfreq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import urllib.request
url = "https://raw.githubusercontent.com/MK316/Class_Spring2022/main/"
file_name1 = "Ch01.Visual.Village.txt"
file_name2 = "Ch02_Livinglight.txt"
urllib.request.urlretrieve(url+file_name1, file_name1)
urllib.request.urlretrieve(url+file_name2, file_name2)
CH01 = open('Ch01.Visual.Village.txt', 'r')
CH02 = open('Ch02_Livinglight.txt', 'r')

# %%
# data
file1 = open("Ch01.Visual.Village.txt")
file2 = open("Ch02_Livinglight.txt")

text1 = file1.read().replace("\n", " ")
text2 = file2.read().replace("\n", " ")

file1.close(); file2.close()

text = text1 + text2

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud().generate(text) 
plt.imshow(wc)
